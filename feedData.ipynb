# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %% [markdown]
# Dataset link - https://www.kaggle.com/c/3926

# %%
donations = pd.read_csv('datasets/donations.csv')
projects = pd.read_csv('datasets/projects.csv')

# %%
donations.head()
# Out:
#                          donationid                         projectid
# 0  431d720bc3dfd75ae445a5eaa0b0638d  ffffac55ee02a49d1abc87ba6fc61135  \
# 1  fcfedba1c8a0ba77d280cace80a909f6  ffffac55ee02a49d1abc87ba6fc61135
# 2  3fa95d29986aa6f401c6719ced3a3ce7  ffffac55ee02a49d1abc87ba6fc61135
# 3  020ad6bd5e88a35741d23b5e08f8b8e8  ffffac55ee02a49d1abc87ba6fc61135
# 4  4b44b03f304d6425ae94446686f93cd6  ffffac55ee02a49d1abc87ba6fc61135
#
#                        donor_acctid      donor_city donor_state  donor_zip
# 0  22cbc920c9b5fa08dfb331422f5926b5  Peachtree City          GA    30269.0  \
# 1  521f1830a77c9dbbf8119d99c6206a16             NaN          GA        NaN
# 2  1e0a63fc8141c7ba26b8b44ca0871b90       Rockville          MD    20853.0
# 3  1d4acb508df29d5f1cc6d382969576cb           Salem          IN    47167.0
# 4  59c3c3cfcccc53ae855f7eee911c478b       anonymous         NaN        0.0
#
#   is_teacher_acct       donation_timestamp  donation_to_project
# 0               f  2011-08-25 14:27:34.807                42.50  \
# 1               f  2011-11-04 07:54:21.552                26.83
# 2               f  2011-11-02 22:53:53.019                55.35
# 3               f  2011-11-03 23:54:01.109                 8.50
# 4               f  2011-11-02 23:21:00.043                20.00
#
#    donation_optional_support  ...  dollar_amount
# 0                       7.50  ...      10_to_100  \
# 1                       4.73  ...      10_to_100
# 2                       0.00  ...      10_to_100
# 3                       1.50  ...      10_to_100
# 4                       0.00  ...      10_to_100
#
#   donation_included_optional_support    payment_method
# 0                                  t  no_cash_received  \
# 1                                  t        creditcard
# 2                                  f  no_cash_received
# 3                                  t            paypal
# 4                                  f  no_cash_received
#
#   payment_included_acct_credit payment_included_campaign_gift_card
# 0                            f                                   t  \
# 1                            f                                   t
# 2                            t                                   f
# 3                            f                                   f
# 4                            f                                   f
#
#   payment_included_web_purchased_gift_card payment_was_promo_matched
# 0                                        f                         f  \
# 1                                        f                         f
# 2                                        f                         f
# 3                                        f                         f
# 4                                        t                         f
#
#   via_giving_page for_honoree
# 0               f           f  \
# 1               f           f
# 2               t           f
# 3               f           f
# 4               t           f
#
#                                     donation_message
# 0  I gave to this project because I support the e...
# 1  I donated because I want to support kids in Ge...
# 2  The Spark's 'pet' projects include those which...
# 3  I gave to this project because Education is im...
# 4  I lent a paw to help the children in this clas...
#
# [5 rows x 21 columns]

# %%
projects.head()
# Out:
#                           projectid                    teacher_acctid
# 0  316ed8fb3b81402ff6ac8f721bb31192  42d43fa6f37314365d08692e08680973  \
# 1  90de744e368a7e4883223ca49318ae30  864eb466462bf704bf7a16a585ef296a
# 2  32943bb1063267de6ed19fc0ceb4b9a7  37f85135259ece793213aca9d8765542
# 3  bb18f409abda2f264d5acda8cab577a9  2133fc46f951f1e7d60645b0f9e48a6c
# 4  24761b686e18e5eace634607acbcc19f  867ff478a63f5457eaf41049536c47cd
#
#                            schoolid  school_ncesid  school_latitude
# 0  c0e6ce89b244764085691a1b8e28cb81   6.362701e+10        36.576340  \
# 1  d711e47810900c96f26a5d0be30c446d   4.837020e+11        32.911179
# 2  665c3613013ba0a66e3a2a26b89f1b68   4.103270e+11        45.166039
# 3  4f12c3fa0c1cce823c7ba1df57e90ccb   3.600153e+11        40.641727
# 4  10179fd362d7b8cf0e89baa1ca3025bb   6.227100e+10        34.043939
#
#    school_longitude  school_city school_state  school_zip school_metro  ...
# 0       -119.608713        Selma           CA     93662.0          NaN  ...  \
# 1        -96.723640       Dallas           TX     75243.0        urban  ...
# 2       -122.414576       Colton           OR     97017.0        rural  ...
# 3        -73.965655     Brooklyn           NY     11226.0        urban  ...
# 4       -118.288371  Los Angeles           CA     90006.0        urban  ...
#
#   resource_type    poverty_level    grade_level fulfillment_labor_materials
# 0         Books  highest poverty     Grades 6-8                        30.0  \
# 1         Books  highest poverty  Grades PreK-2                        30.0
# 2    Technology     high poverty  Grades PreK-2                        30.0
# 3         Books  highest poverty     Grades 3-5                        30.0
# 4         Other  highest poverty  Grades PreK-2                        30.0
#
#   total_price_excluding_optional_support
# 0                                 555.81  \
# 1                                 296.47
# 2                                 430.89
# 3                                 576.07
# 4                                 408.40
#
#   total_price_including_optional_support students_reached
# 0                                 653.89             32.0  \
# 1                                 348.79             22.0
# 2                                 506.93             17.0
# 3                                 677.73             12.0
# 4                                 480.47             24.0
#
#   eligible_double_your_impact_match eligible_almost_home_match date_posted
# 0                                 f                          f  2014-05-12
# 1                                 f                          f  2014-05-12
# 2                                 f                          f  2014-05-11
# 3                                 f                          f  2014-05-11
# 4                                 f                          f  2014-05-11
#
# [5 rows x 35 columns]

# %% [markdown]
# # Data description -
#
# ### donations.csv
# * donationid - unique donation identifier
# * projectid - unique project identifier (project that received the donation)
# * donor_acctid - unique donor identifier (donor that made a donation)
# * donor_city
# * donor_state
# * donor_zip
# * is_teacher_acct - donor is also a teacher
# * donation_timestamp
# * donation_to_project - amount to project, excluding optional support (tip)
# * donation_optional_support - amount of optional support
# * donation_total - donated amount
# * dollar_amount - donated amount in US dollars
# * donation_included_optional_support - whether optional support (tip) was included for DonorsChoose.org
# * payment_method - what card/payment option was used
# * payment_included_acct_credit - whether a portion of a donation used account credits redemption
# * payment_included_campaign_gift_card - whether a portion of a donation included corporate sponsored giftcard
# * payment_included_web_purchased_gift_card - whether a portion of a donation included citizen purchased giftcard (ex: friend buy a giftcard for you)
# * payment_was_promo_matched - whether a donation was matched 1-1 with corporate funds
# * via_giving_page - donation given via a giving / campaign page (example: Mustaches for Kids)
# * for_honoree - donation made for an honoree
# * donation_message - donation comment/message. Used to calcualte great_chat
#
# ### projects.csv
# * projectid - project's unique identifier
# * teacher_acctid - teacher's unique identifier (teacher that created a project)
# * schoolid - school's unique identifier (school where teacher works)
# * school_ncesid - public National Center for Ed Statistics id
# * school_latitude
# * school_longitude
# * school_city
# * school_state
# * school_zip
# * school_metro
# * school_district
# * school_county
# * school_charter - whether a public charter school or not (no private schools in the dataset)
# * school_magnet - whether a public magnet school or not
# * school_year_round - whether a public year round school or not
# * school_nlns - whether a public nlns school or not
# * school_kipp - whether a public kipp school or not
# * school_charter_ready_promise - whether a public ready promise school or not
# * teacher_prefix - teacher's gender
# * teacher_teach_for_america - Teach for America or not
# * teacher_ny_teaching_fellow - New York teaching fellow or not
# * primary_focus_subject - main subject for which project materials are intended
# * primary_focus_area - main subject area for which project materials are intended
# * secondary_focus_subject - secondary subject
# * secondary_focus_area - secondary subject area
# * resource_type - main type of resources requested by a project
# * poverty_level - school's poverty level.
# * highest: 65%+ free of reduced lunch
# * high: 40-64%
# * moderate: 10-39%
# * low: 0-9%
# * grade_level - grade level for which project materials are intended
# * fulfillment_labor_materials - cost of fulfillment
# * total_price_excluding_optional_support - project cost excluding optional tip that donors give to DonorsChoose.org while funding a project
# * total_price_including_optional_support - see above
# * students_reached - number of students impacted by a project (if funded)
# * eligible_double_your_impact_match - project was eligible for a 50% off offer by a corporate partner (logo appears on a project, like Starbucks or Disney)
# * eligible_almost_home_match - project was eligible for a $100 boost offer by a corporate partner
# * date_posted - data a project went live on the site

# %%
donations.shape
# Out:
# (3097989, 21)

# %%
projects.shape
# Out:
# (664098, 35)

# %%
donation_cols = donations.columns
project_cols = projects.columns

donation_cols, project_cols
# Out:
# (Index(['donationid', 'projectid', 'donor_acctid', 'donor_city', 'donor_state',
#         'donor_zip', 'is_teacher_acct', 'donation_timestamp',
#         'donation_to_project', 'donation_optional_support', 'donation_total',
#         'dollar_amount', 'donation_included_optional_support', 'payment_method',
#         'payment_included_acct_credit', 'payment_included_campaign_gift_card',
#         'payment_included_web_purchased_gift_card', 'payment_was_promo_matched',
#         'via_giving_page', 'for_honoree', 'donation_message'],
#        dtype='object'),
#  Index(['projectid', 'teacher_acctid', 'schoolid', 'school_ncesid',
#         'school_latitude', 'school_longitude', 'school_city', 'school_state',
#         'school_zip', 'school_metro', 'school_district', 'school_county',
#         'school_charter', 'school_magnet', 'school_year_round', 'school_nlns',
#         'school_kipp', 'school_charter_ready_promise', 'teacher_prefix',
#         'teacher_teach_for_america', 'teacher_ny_teaching_fellow',
#         'primary_focus_subject', 'primary_focus_area',
#         'secondary_focus_subject', 'secondary_focus_area', 'resource_type',
#         'poverty_level', 'grade_level', 'fulfillment_labor_materials',
#         'total_price_excluding_optional_support',
#         'total_price_including_optional_support', 'students_reached',
#         'eligible_double_your_impact_match', 'eligible_almost_home_match',
#         'date_posted'],
#        dtype='object'))

# %%
donation_dtype = donations.dtypes.to_frame(name='Donations')
donation_dtype
# Out:
#                                          Donations
# donationid                                  object
# projectid                                   object
# donor_acctid                                object
# donor_city                                  object
# donor_state                                 object
# donor_zip                                  float64
# is_teacher_acct                             object
# donation_timestamp                          object
# donation_to_project                        float64
# donation_optional_support                  float64
# donation_total                             float64
# dollar_amount                               object
# donation_included_optional_support          object
# payment_method                              object
# payment_included_acct_credit                object
# payment_included_campaign_gift_card         object
# payment_included_web_purchased_gift_card    object
# payment_was_promo_matched                   object
# via_giving_page                             object
# for_honoree                                 object
# donation_message                            object

# %%
projects_dtypes = projects.dtypes.to_frame(name='Projects')
projects_dtypes
# Out:
#                                        Projects
# projectid                                object
# teacher_acctid                           object
# schoolid                                 object
# school_ncesid                           float64
# school_latitude                         float64
# school_longitude                        float64
# school_city                              object
# school_state                             object
# school_zip                              float64
# school_metro                             object
# school_district                          object
# school_county                            object
# school_charter                           object
# school_magnet                            object
# school_year_round                        object
# school_nlns                              object
# school_kipp                              object
# school_charter_ready_promise             object
# teacher_prefix                           object
# teacher_teach_for_america                object
# teacher_ny_teaching_fellow               object
# primary_focus_subject                    object
# primary_focus_area                       object
# secondary_focus_subject                  object
# secondary_focus_area                     object
# resource_type                            object
# poverty_level                            object
# grade_level                              object
# fulfillment_labor_materials             float64
# total_price_excluding_optional_support  float64
# total_price_including_optional_support  float64
# students_reached                        float64
# eligible_double_your_impact_match        object
# eligible_almost_home_match               object
# date_posted                              object

# %%
import sqlalchemy as db

engine = db.create_engine("mysql://ayush:ayush@localhost:3306/lsdb")
conn = engine.connect()
metadata = db.MetaData()

# %%
try:
    frame = projects.to_sql('projects', conn, if_exists='fail')
except Exception as ex:
    print(ex)
else:
    print("Table is created successfully")
# Out:
# Table is created successfully

# %% [markdown]
# The column `donation_message` causes error during the upload process. Thus dropping the column ...

# %%
donations = donations.dropna()
new_donations = donations.drop(['donation_message'], axis=1)
new_donations.head()
# Out:
#                           donationid                         projectid
# 0   431d720bc3dfd75ae445a5eaa0b0638d  ffffac55ee02a49d1abc87ba6fc61135  \
# 2   3fa95d29986aa6f401c6719ced3a3ce7  ffffac55ee02a49d1abc87ba6fc61135
# 3   020ad6bd5e88a35741d23b5e08f8b8e8  ffffac55ee02a49d1abc87ba6fc61135
# 15  9e0f234dfa2982619dacd0635019d53d  ffff2d9c769c8fb5335e949c615425eb
# 16  fdcd840e3dd57016590cb8a69aed0c09  ffff2d9c769c8fb5335e949c615425eb
#
#                         donor_acctid      donor_city donor_state  donor_zip
# 0   22cbc920c9b5fa08dfb331422f5926b5  Peachtree City          GA    30269.0  \
# 2   1e0a63fc8141c7ba26b8b44ca0871b90       Rockville          MD    20853.0
# 3   1d4acb508df29d5f1cc6d382969576cb           Salem          IN    47167.0
# 15  af1f03b856fc2979c01a6ad8b61f6fbe       Pocatello          ID    83201.0
# 16  af1f03b856fc2979c01a6ad8b61f6fbe       Pocatello          ID    83201.0
#
#    is_teacher_acct       donation_timestamp  donation_to_project
# 0                f  2011-08-25 14:27:34.807                42.50  \
# 2                f  2011-11-02 22:53:53.019                55.35
# 3                f  2011-11-03 23:54:01.109                 8.50
# 15               f   2013-05-08 12:58:55.38                68.00
# 16               f  2013-05-08 13:18:21.233                12.75
#
#     donation_optional_support  donation_total dollar_amount
# 0                        7.50           50.00     10_to_100  \
# 2                        0.00           55.35     10_to_100
# 3                        1.50           10.00     10_to_100
# 15                      12.00           80.00     10_to_100
# 16                       2.25           15.00     10_to_100
#
#    donation_included_optional_support    payment_method
# 0                                   t  no_cash_received  \
# 2                                   f  no_cash_received
# 3                                   t            paypal
# 15                                  t        creditcard
# 16                                  t  no_cash_received
#
#    payment_included_acct_credit payment_included_campaign_gift_card
# 0                             f                                   t  \
# 2                             t                                   f
# 3                             f                                   f
# 15                            f                                   t
# 16                            f                                   t
#
#    payment_included_web_purchased_gift_card payment_was_promo_matched
# 0                                         f                         f  \
# 2                                         f                         f
# 3                                         f                         f
# 15                                        f                         f
# 16                                        f                         f
#
#    via_giving_page for_honoree
# 0                f           f
# 2                t           f
# 3                f           f
# 15               f           f
# 16               f           f

# %%
try:
    frame_2 = new_donations.to_sql('donations', conn, if_exists='fail')
except Exception as ex:
    print(ex)
else:
    print("Table is created successfully")
# Out:
# Table is created successfully

# %%
db_projects = db.Table('projects', metadata, autoload_with=engine)
print(db_projects.columns.keys())
# Out:
# ['index', 'projectid', 'teacher_acctid', 'schoolid', 'school_ncesid', 'school_latitude', 'school_longitude', 'school_city', 'school_state', 'school_zip', 'school_metro', 'school_district', 'school_county', 'school_charter', 'school_magnet', 'school_year_round', 'school_nlns', 'school_kipp', 'school_charter_ready_promise', 'teacher_prefix', 'teacher_teach_for_america', 'teacher_ny_teaching_fellow', 'primary_focus_subject', 'primary_focus_area', 'secondary_focus_subject', 'secondary_focus_area', 'resource_type', 'poverty_level', 'grade_level', 'fulfillment_labor_materials', 'total_price_excluding_optional_support', 'total_price_including_optional_support', 'students_reached', 'eligible_double_your_impact_match', 'eligible_almost_home_match', 'date_posted']

# %%
db_donations = db.Table('donations', metadata, autoload_with=engine)
print(db_donations.columns.keys())
# Out:
# ['index', 'donationid', 'projectid', 'donor_acctid', 'donor_city', 'donor_state', 'donor_zip', 'is_teacher_acct', 'donation_timestamp', 'donation_to_project', 'donation_optional_support', 'donation_total', 'dollar_amount', 'donation_included_optional_support', 'payment_method', 'payment_included_acct_credit', 'payment_included_campaign_gift_card', 'payment_included_web_purchased_gift_card', 'payment_was_promo_matched', 'via_giving_page', 'for_honoree']

# %%
from pymongo import MongoClient

client = MongoClient('localhost', 27017)
db = client['lsdb']
collection_project = db['projects']
collection_donation = db['donations']

# %% [markdown]
# ### Before executing above cell, use following commands in MongoDb shell:
#
# * use lsdb
# * db.createCollection('projects')
# * db.createCollection('donations')

# %%
projects.rename(columns={'index':'_id'}, inplace=True)

# %%
projects.reset_index(inplace=True)
project_dict = projects.to_dict("records")

# %%
project_dict[0]
# Out:
# {'_id': 0,
#  'projectid': '316ed8fb3b81402ff6ac8f721bb31192',
#  'teacher_acctid': '42d43fa6f37314365d08692e08680973',
#  'schoolid': 'c0e6ce89b244764085691a1b8e28cb81',
#  'school_ncesid': 63627006187.0,
#  'school_latitude': 36.57634,
#  'school_longitude': -119.608713,
#  'school_city': 'Selma',
#  'school_state': 'CA',
#  'school_zip': 93662.0,
#  'school_metro': nan,
#  'school_district': 'Selma Unified Sch District',
#  'school_county': 'Fresno',
#  'school_charter': 'f',
#  'school_magnet': 'f',
#  'school_year_round': 'f',
#  'school_nlns': 'f',
#  'school_kipp': 'f',
#  'school_charter_ready_promise': 'f',
#  'teacher_prefix': 'Mrs.',
#  'teacher_teach_for_america': 'f',
#  'teacher_ny_teaching_fellow': 'f',
#  'primary_focus_subject': 'Literature & Writing',
#  'primary_focus_area': 'Literacy & Language',
#  'secondary_focus_subject': 'College & Career Prep',
#  'secondary_focus_area': 'Applied Learning',
#  'resource_type': 'Books',
#  'poverty_level': 'highest poverty',
#  'grade_level': 'Grades 6-8',
#  'fulfillment_labor_materials': 30.0,
#  'total_price_excluding_optional_support': 555.81,
#  'total_price_including_optional_support': 653.89,
#  'students_reached': 32.0,
#  'eligible_double_your_impact_match': 'f',
#  'eligible_almost_home_match': 'f',
#  'date_posted': '2014-05-12'}

# %%
collection_project.insert_many(project_dict)

# %%
new_donations.rename(columns={'index': '_id'}, inplace=True)

# %%
new_donations.reset_index(inplace=True)
donation_dict = new_donations.to_dict("records")

# %%
collection_donation.insert_many(donation_dict)

# %% [markdown]
# Check the database by printing the first 10 rows of both the tables

# %%
project_cursor = collection_project.find().limit(10)
for record in project_cursor:
    print(record)
# Out:
# {'_id': 0, 'projectid': '316ed8fb3b81402ff6ac8f721bb31192', 'teacher_acctid': '42d43fa6f37314365d08692e08680973', 'schoolid': 'c0e6ce89b244764085691a1b8e28cb81', 'school_ncesid': 63627006187.0, 'school_latitude': 36.57634, 'school_longitude': -119.608713, 'school_city': 'Selma', 'school_state': 'CA', 'school_zip': 93662.0, 'school_metro': nan, 'school_district': 'Selma Unified Sch District', 'school_county': 'Fresno', 'school_charter': 'f', 'school_magnet': 'f', 'school_year_round': 'f', 'school_nlns': 'f', 'school_kipp': 'f', 'school_charter_ready_promise': 'f', 'teacher_prefix': 'Mrs.', 'teacher_teach_for_america': 'f', 'teacher_ny_teaching_fellow': 'f', 'primary_focus_subject': 'Literature & Writing', 'primary_focus_area': 'Literacy & Language', 'secondary_focus_subject': 'College & Career Prep', 'secondary_focus_area': 'Applied Learning', 'resource_type': 'Books', 'poverty_level': 'highest poverty', 'grade_level': 'Grades 6-8', 'fulfillment_labor_materials': 30.0, 'total_price_excluding_optional_support': 555.81, 'total_price_including_optional_support': 653.89, 'students_reached': 32.0, 'eligible_double_your_impact_match': 'f', 'eligible_almost_home_match': 'f', 'date_posted': '2014-05-12'}
# {'_id': 1, 'projectid': '90de744e368a7e4883223ca49318ae30', 'teacher_acctid': '864eb466462bf704bf7a16a585ef296a', 'schoolid': 'd711e47810900c96f26a5d0be30c446d', 'school_ncesid': 483702008193.0, 'school_latitude': 32.911179, 'school_longitude': -96.72364, 'school_city': 'Dallas', 'school_state': 'TX', 'school_zip': 75243.0, 'school_metro': 'urban', 'school_district': 'Richardson Ind School District', 'school_county': 'Dallas', 'school_charter': 'f', 'school_magnet': 'f', 'school_year_round': 'f', 'school_nlns': 'f', 'school_kipp': 'f', 'school_charter_ready_promise': 'f', 'teacher_prefix': 'Mrs.', 'teacher_teach_for_america': 'f', 'teacher_ny_teaching_fellow': 'f', 'primary_focus_subject': 'Literacy', 'primary_focus_area': 'Literacy & Language', 'secondary_focus_subject': 'ESL', 'secondary_focus_area': 'Literacy & Language', 'resource_type': 'Books', 'poverty_level': 'highest poverty', 'grade_level': 'Grades PreK-2', 'fulfillment_labor_materials': 30.0, 'total_price_excluding_optional_support': 296.47, 'total_price_including_optional_support': 348.79, 'students_reached': 22.0, 'eligible_double_your_impact_match': 'f', 'eligible_almost_home_match': 'f', 'date_posted': '2014-05-12'}
# {'_id': 2, 'projectid': '32943bb1063267de6ed19fc0ceb4b9a7', 'teacher_acctid': '37f85135259ece793213aca9d8765542', 'schoolid': '665c3613013ba0a66e3a2a26b89f1b68', 'school_ncesid': 410327000109.0, 'school_latitude': 45.166039, 'school_longitude': -122.414576, 'school_city': 'Colton', 'school_state': 'OR', 'school_zip': 97017.0, 'school_metro': 'rural', 'school_district': 'Colton School District 53', 'school_county': 'Clackamas', 'school_charter': 'f', 'school_magnet': 'f', 'school_year_round': 'f', 'school_nlns': 'f', 'school_kipp': 'f', 'school_charter_ready_promise': 'f', 'teacher_prefix': 'Mr.', 'teacher_teach_for_america': 'f', 'teacher_ny_teaching_fellow': 'f', 'primary_focus_subject': 'Literacy', 'primary_focus_area': 'Literacy & Language', 'secondary_focus_subject': 'Mathematics', 'secondary_focus_area': 'Math & Science', 'resource_type': 'Technology', 'poverty_level': 'high poverty', 'grade_level': 'Grades PreK-2', 'fulfillment_labor_materials': 30.0, 'total_price_excluding_optional_support': 430.89, 'total_price_including_optional_support': 506.93, 'students_reached': 17.0, 'eligible_double_your_impact_match': 'f', 'eligible_almost_home_match': 'f', 'date_posted': '2014-05-11'}
# {'_id': 3, 'projectid': 'bb18f409abda2f264d5acda8cab577a9', 'teacher_acctid': '2133fc46f951f1e7d60645b0f9e48a6c', 'schoolid': '4f12c3fa0c1cce823c7ba1df57e90ccb', 'school_ncesid': 360015302507.0, 'school_latitude': 40.641727, 'school_longitude': -73.965655, 'school_city': 'Brooklyn', 'school_state': 'NY', 'school_zip': 11226.0, 'school_metro': 'urban', 'school_district': 'New York City Dept Of Ed', 'school_county': 'Kings (Brooklyn)', 'school_charter': 'f', 'school_magnet': 't', 'school_year_round': 'f', 'school_nlns': 'f', 'school_kipp': 'f', 'school_charter_ready_promise': 'f', 'teacher_prefix': 'Mr.', 'teacher_teach_for_america': 't', 'teacher_ny_teaching_fellow': 'f', 'primary_focus_subject': 'Social Sciences', 'primary_focus_area': 'History & Civics', 'secondary_focus_subject': 'Special Needs', 'secondary_focus_area': 'Special Needs', 'resource_type': 'Books', 'poverty_level': 'highest poverty', 'grade_level': 'Grades 3-5', 'fulfillment_labor_materials': 30.0, 'total_price_excluding_optional_support': 576.07, 'total_price_including_optional_support': 677.73, 'students_reached': 12.0, 'eligible_double_your_impact_match': 'f', 'eligible_almost_home_match': 'f', 'date_posted': '2014-05-11'}
# {'_id': 4, 'projectid': '24761b686e18e5eace634607acbcc19f', 'teacher_acctid': '867ff478a63f5457eaf41049536c47cd', 'schoolid': '10179fd362d7b8cf0e89baa1ca3025bb', 'school_ncesid': 62271003157.0, 'school_latitude': 34.043939, 'school_longitude': -118.288371, 'school_city': 'Los Angeles', 'school_state': 'CA', 'school_zip': 90006.0, 'school_metro': 'urban', 'school_district': 'Los Angeles Unif Sch Dist', 'school_county': 'Los Angeles', 'school_charter': 'f', 'school_magnet': 'f', 'school_year_round': 'f', 'school_nlns': 'f', 'school_kipp': 'f', 'school_charter_ready_promise': 'f', 'teacher_prefix': 'Ms.', 'teacher_teach_for_america': 'f', 'teacher_ny_teaching_fellow': 'f', 'primary_focus_subject': 'Mathematics', 'primary_focus_area': 'Math & Science', 'secondary_focus_subject': 'Literacy', 'secondary_focus_area': 'Literacy & Language', 'resource_type': 'Other', 'poverty_level': 'highest poverty', 'grade_level': 'Grades PreK-2', 'fulfillment_labor_materials': 30.0, 'total_price_excluding_optional_support': 408.4, 'total_price_including_optional_support': 480.47, 'students_reached': 24.0, 'eligible_double_your_impact_match': 'f', 'eligible_almost_home_match': 'f', 'date_posted': '2014-05-11'}
# {'_id': 5, 'projectid': 'eac7d156205f1333de3887d656f46611', 'teacher_acctid': 'ff064802c18e68db7ddb7ea0bf7732e8', 'schoolid': '929336e5a242d2e67f1a591196ba7701', 'school_ncesid': 40187001058.0, 'school_latitude': 33.298792, 'school_longitude': -111.827793, 'school_city': 'Chandler', 'school_state': 'AZ', 'school_zip': 85225.0, 'school_metro': 'suburban', 'school_district': 'Chandler Unif School Dist 80', 'school_county': 'Maricopa', 'school_charter': 'f', 'school_magnet': 'f', 'school_year_round': 't', 'school_nlns': 'f', 'school_kipp': 'f', 'school_charter_ready_promise': 'f', 'teacher_prefix': 'Mrs.', 'teacher_teach_for_america': 'f', 'teacher_ny_teaching_fellow': 'f', 'primary_focus_subject': 'Literature & Writing', 'primary_focus_area': 'Literacy & Language', 'secondary_focus_subject': 'ESL', 'secondary_focus_area': 'Literacy & Language', 'resource_type': 'Technology', 'poverty_level': 'highest poverty', 'grade_level': 'Grades 3-5', 'fulfillment_labor_materials': 30.0, 'total_price_excluding_optional_support': 750.92, 'total_price_including_optional_support': 883.44, 'students_reached': 20.0, 'eligible_double_your_impact_match': 'f', 'eligible_almost_home_match': 'f', 'date_posted': '2014-05-11'}
# {'_id': 6, 'projectid': '5a3bfdf2e05781ccd0654dee0d51d1cd', 'teacher_acctid': '085794a9e315b88cb7aec548831572f5', 'schoolid': 'dc34b021fd177cfdb22f22055ca9d04f', 'school_ncesid': 10060000256.0, 'school_latitude': 32.838778, 'school_longitude': -85.517527, 'school_city': 'Lafayette', 'school_state': 'AL', 'school_zip': 36862.0, 'school_metro': 'rural', 'school_district': 'Chambers Co School District', 'school_county': 'Chambers', 'school_charter': 'f', 'school_magnet': 'f', 'school_year_round': 'f', 'school_nlns': 'f', 'school_kipp': 'f', 'school_charter_ready_promise': 'f', 'teacher_prefix': 'Mr.', 'teacher_teach_for_america': 'f', 'teacher_ny_teaching_fellow': 'f', 'primary_focus_subject': 'Gym & Fitness', 'primary_focus_area': 'Health & Sports', 'secondary_focus_subject': nan, 'secondary_focus_area': nan, 'resource_type': 'Supplies', 'poverty_level': 'highest poverty', 'grade_level': 'Grades PreK-2', 'fulfillment_labor_materials': 30.0, 'total_price_excluding_optional_support': 2291.48, 'total_price_including_optional_support': 2695.86, 'students_reached': 320.0, 'eligible_double_your_impact_match': 'f', 'eligible_almost_home_match': 'f', 'date_posted': '2014-05-11'}
# {'_id': 7, 'projectid': 'afda16eb54d8992db7bb42923b2a0c69', 'teacher_acctid': '1d94a31c2dc38d51350eb26a4a2d892c', 'schoolid': '86fff7caa07e4f595a716d8a1960f09e', 'school_ncesid': 130129000571.0, 'school_latitude': 33.896013, 'school_longitude': -84.554213, 'school_city': 'Marietta', 'school_state': 'GA', 'school_zip': 30060.0, 'school_metro': nan, 'school_district': 'Cobb Co School District', 'school_county': 'Cobb', 'school_charter': 'f', 'school_magnet': 'f', 'school_year_round': 'f', 'school_nlns': 'f', 'school_kipp': 'f', 'school_charter_ready_promise': 'f', 'teacher_prefix': 'Mrs.', 'teacher_teach_for_america': 'f', 'teacher_ny_teaching_fellow': 'f', 'primary_focus_subject': 'Literacy', 'primary_focus_area': 'Literacy & Language', 'secondary_focus_subject': nan, 'secondary_focus_area': nan, 'resource_type': 'Books', 'poverty_level': 'highest poverty', 'grade_level': 'Grades PreK-2', 'fulfillment_labor_materials': 30.0, 'total_price_excluding_optional_support': 459.36, 'total_price_including_optional_support': 540.42, 'students_reached': 18.0, 'eligible_double_your_impact_match': 'f', 'eligible_almost_home_match': 'f', 'date_posted': '2014-05-11'}
# {'_id': 8, 'projectid': '2ab3efb23acc84017cd7896f62c2e889', 'teacher_acctid': '5a497c425e05bb193564ef3ce2cbf3b6', 'schoolid': 'ed170a147cd8ee2391b54b2f8b206160', 'school_ncesid': 261200001297.0, 'school_latitude': 42.422054, 'school_longitude': -83.209656, 'school_city': 'Detroit', 'school_state': 'MI', 'school_zip': 48235.0, 'school_metro': 'urban', 'school_district': 'Detroit Public School District', 'school_county': 'Wayne', 'school_charter': 't', 'school_magnet': 'f', 'school_year_round': 'f', 'school_nlns': 'f', 'school_kipp': 'f', 'school_charter_ready_promise': 'f', 'teacher_prefix': 'Ms.', 'teacher_teach_for_america': 'f', 'teacher_ny_teaching_fellow': 'f', 'primary_focus_subject': 'Literacy', 'primary_focus_area': 'Literacy & Language', 'secondary_focus_subject': nan, 'secondary_focus_area': nan, 'resource_type': 'Technology', 'poverty_level': 'highest poverty', 'grade_level': 'Grades PreK-2', 'fulfillment_labor_materials': 30.0, 'total_price_excluding_optional_support': 325.39, 'total_price_including_optional_support': 382.81, 'students_reached': 25.0, 'eligible_double_your_impact_match': 'f', 'eligible_almost_home_match': 'f', 'date_posted': '2014-05-11'}
# {'_id': 9, 'projectid': '3118962680bb062323c3566197487315', 'teacher_acctid': 'eb0855cc6ea55d173ca8f8e4fd6a9e18', 'schoolid': '71b4dee33799c2111773bb4444766bf0', 'school_ncesid': 340264001386.0, 'school_latitude': 39.951767, 'school_longitude': -75.117188, 'school_city': 'Camden', 'school_state': 'NJ', 'school_zip': 8102.0, 'school_metro': 'urban', 'school_district': 'Camden City School District', 'school_county': 'Camden', 'school_charter': 'f', 'school_magnet': 'f', 'school_year_round': 'f', 'school_nlns': 'f', 'school_kipp': 'f', 'school_charter_ready_promise': 'f', 'teacher_prefix': 'Mr.', 'teacher_teach_for_america': 'f', 'teacher_ny_teaching_fellow': 'f', 'primary_focus_subject': 'College & Career Prep', 'primary_focus_area': 'Applied Learning', 'secondary_focus_subject': nan, 'secondary_focus_area': nan, 'resource_type': 'Technology', 'poverty_level': 'highest poverty', 'grade_level': 'Grades PreK-2', 'fulfillment_labor_materials': 30.0, 'total_price_excluding_optional_support': 567.84, 'total_price_including_optional_support': 668.05, 'students_reached': 28.0, 'eligible_double_your_impact_match': 'f', 'eligible_almost_home_match': 'f', 'date_posted': '2014-05-11'}

# %%
donation_cursor = collection_donation.find().limit(10)
for record in donation_cursor:
    print(record)
# Out:
# {'_id': 0, 'donationid': '431d720bc3dfd75ae445a5eaa0b0638d', 'projectid': 'ffffac55ee02a49d1abc87ba6fc61135', 'donor_acctid': '22cbc920c9b5fa08dfb331422f5926b5', 'donor_city': 'Peachtree City', 'donor_state': 'GA', 'donor_zip': 30269.0, 'is_teacher_acct': 'f', 'donation_timestamp': '2011-08-25 14:27:34.807', 'donation_to_project': 42.5, 'donation_optional_support': 7.5, 'donation_total': 50.0, 'dollar_amount': '10_to_100', 'donation_included_optional_support': 't', 'payment_method': 'no_cash_received', 'payment_included_acct_credit': 'f', 'payment_included_campaign_gift_card': 't', 'payment_included_web_purchased_gift_card': 'f', 'payment_was_promo_matched': 'f', 'via_giving_page': 'f', 'for_honoree': 'f'}
# {'_id': 2, 'donationid': '3fa95d29986aa6f401c6719ced3a3ce7', 'projectid': 'ffffac55ee02a49d1abc87ba6fc61135', 'donor_acctid': '1e0a63fc8141c7ba26b8b44ca0871b90', 'donor_city': 'Rockville', 'donor_state': 'MD', 'donor_zip': 20853.0, 'is_teacher_acct': 'f', 'donation_timestamp': '2011-11-02 22:53:53.019', 'donation_to_project': 55.35, 'donation_optional_support': 0.0, 'donation_total': 55.35, 'dollar_amount': '10_to_100', 'donation_included_optional_support': 'f', 'payment_method': 'no_cash_received', 'payment_included_acct_credit': 't', 'payment_included_campaign_gift_card': 'f', 'payment_included_web_purchased_gift_card': 'f', 'payment_was_promo_matched': 'f', 'via_giving_page': 't', 'for_honoree': 'f'}
# {'_id': 3, 'donationid': '020ad6bd5e88a35741d23b5e08f8b8e8', 'projectid': 'ffffac55ee02a49d1abc87ba6fc61135', 'donor_acctid': '1d4acb508df29d5f1cc6d382969576cb', 'donor_city': 'Salem', 'donor_state': 'IN', 'donor_zip': 47167.0, 'is_teacher_acct': 'f', 'donation_timestamp': '2011-11-03 23:54:01.109', 'donation_to_project': 8.5, 'donation_optional_support': 1.5, 'donation_total': 10.0, 'dollar_amount': '10_to_100', 'donation_included_optional_support': 't', 'payment_method': 'paypal', 'payment_included_acct_credit': 'f', 'payment_included_campaign_gift_card': 'f', 'payment_included_web_purchased_gift_card': 'f', 'payment_was_promo_matched': 'f', 'via_giving_page': 'f', 'for_honoree': 'f'}
# {'_id': 15, 'donationid': '9e0f234dfa2982619dacd0635019d53d', 'projectid': 'ffff2d9c769c8fb5335e949c615425eb', 'donor_acctid': 'af1f03b856fc2979c01a6ad8b61f6fbe', 'donor_city': 'Pocatello', 'donor_state': 'ID', 'donor_zip': 83201.0, 'is_teacher_acct': 'f', 'donation_timestamp': '2013-05-08 12:58:55.38', 'donation_to_project': 68.0, 'donation_optional_support': 12.0, 'donation_total': 80.0, 'dollar_amount': '10_to_100', 'donation_included_optional_support': 't', 'payment_method': 'creditcard', 'payment_included_acct_credit': 'f', 'payment_included_campaign_gift_card': 't', 'payment_included_web_purchased_gift_card': 'f', 'payment_was_promo_matched': 'f', 'via_giving_page': 'f', 'for_honoree': 'f'}
# {'_id': 16, 'donationid': 'fdcd840e3dd57016590cb8a69aed0c09', 'projectid': 'ffff2d9c769c8fb5335e949c615425eb', 'donor_acctid': 'af1f03b856fc2979c01a6ad8b61f6fbe', 'donor_city': 'Pocatello', 'donor_state': 'ID', 'donor_zip': 83201.0, 'is_teacher_acct': 'f', 'donation_timestamp': '2013-05-08 13:18:21.233', 'donation_to_project': 12.75, 'donation_optional_support': 2.25, 'donation_total': 15.0, 'dollar_amount': '10_to_100', 'donation_included_optional_support': 't', 'payment_method': 'no_cash_received', 'payment_included_acct_credit': 'f', 'payment_included_campaign_gift_card': 't', 'payment_included_web_purchased_gift_card': 'f', 'payment_was_promo_matched': 'f', 'via_giving_page': 'f', 'for_honoree': 'f'}
# {'_id': 22, 'donationid': '58cd1ebb1987a4805130405e65a5317c', 'projectid': 'ffff2d9c769c8fb5335e949c615425eb', 'donor_acctid': 'ad64435ac0cc5bac933efaf360e46eaa', 'donor_city': 'Rigby', 'donor_state': 'ID', 'donor_zip': 83442.0, 'is_teacher_acct': 'f', 'donation_timestamp': '2013-03-08 13:55:16.618', 'donation_to_project': 42.5, 'donation_optional_support': 7.5, 'donation_total': 50.0, 'dollar_amount': '10_to_100', 'donation_included_optional_support': 't', 'payment_method': 'creditcard', 'payment_included_acct_credit': 'f', 'payment_included_campaign_gift_card': 'f', 'payment_included_web_purchased_gift_card': 'f', 'payment_was_promo_matched': 't', 'via_giving_page': 't', 'for_honoree': 'f'}
# {'_id': 25, 'donationid': '474fbf88996111159655a36ad588c7c1', 'projectid': 'fffee68353ade53e7692b23098096683', 'donor_acctid': 'dddd29e34a0e4d889e65ccaa6efc44cf', 'donor_city': 'Dillon', 'donor_state': 'SC', 'donor_zip': 29536.0, 'is_teacher_acct': 't', 'donation_timestamp': '2010-11-18 14:54:08.782', 'donation_to_project': 4.25, 'donation_optional_support': 0.75, 'donation_total': 5.0, 'dollar_amount': 'under_10', 'donation_included_optional_support': 't', 'payment_method': 'no_cash_received', 'payment_included_acct_credit': 'f', 'payment_included_campaign_gift_card': 't', 'payment_included_web_purchased_gift_card': 'f', 'payment_was_promo_matched': 'f', 'via_giving_page': 'f', 'for_honoree': 'f'}
# {'_id': 30, 'donationid': '253f4f61b814bcba8f851c7af6a007b7', 'projectid': 'fffe598a41270538eab48432513513ab', 'donor_acctid': 'fa35bf11ed7636b012460477e9bbdfeb', 'donor_city': 'Battlefield', 'donor_state': 'MO', 'donor_zip': 65619.0, 'is_teacher_acct': 'f', 'donation_timestamp': '2011-03-29 00:00:00', 'donation_to_project': 8.5, 'donation_optional_support': 1.5, 'donation_total': 10.0, 'dollar_amount': '10_to_100', 'donation_included_optional_support': 't', 'payment_method': 'paypal', 'payment_included_acct_credit': 'f', 'payment_included_campaign_gift_card': 'f', 'payment_included_web_purchased_gift_card': 'f', 'payment_was_promo_matched': 'f', 'via_giving_page': 't', 'for_honoree': 'f'}
# {'_id': 38, 'donationid': '766ce8d9887d991a8e93427e4f5fa239', 'projectid': 'fffe598a41270538eab48432513513ab', 'donor_acctid': 'c83fb6e7f8936cb0424dd405cb272a46', 'donor_city': 'College Park', 'donor_state': 'GA', 'donor_zip': 30349.0, 'is_teacher_acct': 't', 'donation_timestamp': '2011-01-08 17:20:39.181', 'donation_to_project': 4.25, 'donation_optional_support': 0.75, 'donation_total': 5.0, 'dollar_amount': 'under_10', 'donation_included_optional_support': 't', 'payment_method': 'no_cash_received', 'payment_included_acct_credit': 't', 'payment_included_campaign_gift_card': 'f', 'payment_included_web_purchased_gift_card': 'f', 'payment_was_promo_matched': 'f', 'via_giving_page': 'f', 'for_honoree': 'f'}
# {'_id': 45, 'donationid': 'd5951aff8024fc4f11ee7ca7dfa61897', 'projectid': 'fffe45b28ea6f2889de1e3f797fb31a3', 'donor_acctid': '80fa64b72fd3c9e0443b3c5d03df2467', 'donor_city': 'Denver', 'donor_state': 'CO', 'donor_zip': 80203.0, 'is_teacher_acct': 'f', 'donation_timestamp': '2012-02-16 21:50:16.346', 'donation_to_project': 12.32, 'donation_optional_support': 2.18, 'donation_total': 14.5, 'dollar_amount': '10_to_100', 'donation_included_optional_support': 't', 'payment_method': 'creditcard', 'payment_included_acct_credit': 'f', 'payment_included_campaign_gift_card': 'f', 'payment_included_web_purchased_gift_card': 'f', 'payment_was_promo_matched': 't', 'via_giving_page': 't', 'for_honoree': 'f'}
